# %% [markdown]
# ## Tarea semanal 13
# ### Teoria de los circuitos 2
# #### Destefano, Martin

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Para este ejercicio es necesario incluir la RL en el cuadripolo, se puede estudiar como si fuese otro en cascada.
#
# Entonces:
#
# $$ \frac{I2}{I1} = H\frac{s^2+5s+4}{s^2+8s+12} = \frac{Z_{21}}{Z_{22}} $$
#
# Despejando:
#
# $$ Z_{22} = \frac{6(s^2+8s+12)}{s^2+5s+4} $$
#
# Graficamente:
#
# ![image-2.png](attachment:image-2.png)
#
# Analiticamente, como remuevo desde el final, lo primero que saco es RL = 1:
#
# $$ Z_{2} = \frac{6(s^2+8s+12)}{s^2+5s+4} - 1 = \frac{5s^2+43s+68)}{s^2+5s+4} $$
#
# Calculo el residuo del primer tanque serie:
#
# K1 = 10
#
# Entonces:
#
# $$ Z3 = \frac{5s^2+43s+68)}{s^2+5s+4} - \frac{10}{s+1} = \frac{5s^2+33s+28}{s^2+5s+4} $$
#
# $$ Z3 = \frac{s+\frac{28}{5}}{s+4} $$
#
# Calculo K2 = 8
#
# $$ Z4 = \frac{5(s+\frac{28}{5})}{s+4} - \frac{8}{s+4} = 5 $$
#
# R1 = 1
# R2 = 2
# C2 = 1/10
# R4 = 5
# C1 = 1/8
# R3 = 10
#
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Teniendo en cuenta la siguiente restriccion externa al cuadripolo:
# $$ I_{2} = -\frac{V_{2}}{R_{L}} $$
#
# Y que parametros Z:
#
# $$ V_{2} = I_{1}Z_{21} + (\frac{-V_{2}}{RL})Z_{22} $$
# $$ V_{2} + \frac{V_{2}}{RL} = I_{1}Z_{21} $$
#
# $$ \frac{V_{2}}{I_{1}} = \frac{Z_{21}}{1+\frac{Z_{22}}{RL}} $$
# Si tomamos como norma RL = 1
# $$ \frac{V_{2}}{I_{1}} = \frac{Z_{21}}{1+{Z_{22}}} $$
#
# Teniendo en cuenta que $Z_{21}$ es siempre impar en no disipativas, podemos plantear el polinomio D a partir de esa condicion, sabiendo la condicion de impar/par o par/impar.

# %% [markdown]
# $$ \frac{V_{2}}{I_{1}} = \frac{\frac{s^2+9}{s^3+2s}}{1+\frac{2s^2+1}{s^3+2s}} $$
#
# Con $Z_{22}$ sintetizo:
#
# Sintesis grafica:
# ![image.png](attachment:image.png)

# %% [markdown]
# Calculo $k_{\infty} = 1/5$
#
# Remuevo:
#
# $$ Y2 = \frac{s^3+2s}{2s^2+1} - s/5 = \frac{\frac{3}{5}s^3+\frac{9}{5}s}{2s^2+1}$$
#
# Calculo K1 para el tanque LC serie:
#
# K1 = 25/18
#
# $$ Z3 = \frac{\frac{3}{5}s^3+\frac{9}{5}s}{2s^2+1} - \frac{2\frac{25}{18}s}{s^2+3} = \frac{5}{9s} $$
#
# - C1 = 1/5
# - C2 = 9/25
# - L1 = 25/18
# - C3 = 9/5
#
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)
