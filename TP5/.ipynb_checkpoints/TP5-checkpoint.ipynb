# %% [markdown]
# ![image.png](./logo_UTN.svg)
#
# <center> <h1>TRABAJO PRACTICO N° 5</h1> </center>
#
# <center> <h2> Grupo 3 </h2> </center>
# <left> <h3> Integrantes: </h3> </left>
# <left> <h4> Destefano, Martin </h4> </left>
# <left> <h4> Pepe, Nicolas </h4> </left>
# <left> <h4> Ruffa, Giuliana </h4> </left>
# <left> <h4> Sandomir, Uriel </h4> </left>

# %% [markdown]
# ## Ejercicio 3
#
#
#
#
# ## Punto A
#
# Expresamos la transferencia 1 y 2:
#
# $$ H_{1} = 1+Z^{-1} $$
# $$ H_{2} = 1+Z^{-1}+Z^{-2} $$
#
# $$ H_{1}(e^{-j\Omega}) = e^{-j\frac{\Omega}{2}}( e^{-j\frac{\Omega}{2}} +   e^{j\frac{\Omega}{2}}) $$
#
# $$ |H_{1}(e^{-j\Omega})| = 2cos(\frac{\Omega}{2}) $$
#
# $$ \Phi_{1} = -\frac{\Omega}{2} $$
#
# $$ H_{2}(e^{-j\Omega}) = e^{-j\Omega}( e^{-j\Omega} +   e^{j\Omega} + 1 ) $$
#
# $$ |H_{2}(e^{-j\Omega})| = 2cos(\Omega) + 1 $$
#
# $$ \Phi_{2} = -\Omega $$
#
# Dividiendo por la cantidad de muestras, obtendriamos la media aritmetica.

# %%
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.freqz.html 
# Punto A - H1 
import numpy as np
import scipy.signal as signal
import matplotlib as mpl
import matplotlib.pyplot as plt
import math as m
import splane as sp


np.seterr(divide = 'ignore') 


num = [1, 1]
den = [1]
 


w,h = signal.freqz(num,den)


fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample]')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid(True)
ax2.axis('tight')
plt.show()

# %%
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.freqz.html 
# Punto A - H2 
import numpy as np
import scipy.signal as signal
import matplotlib as mpl
import matplotlib.pyplot as plt
import math as m
import splane as sp


np.seterr(divide = 'ignore') 

num = [1,1, 1]
den = [1]
 


w,h = signal.freqz(num,den)


fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample]')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid(True)
ax2.axis('tight')
plt.show()

# %% [markdown]
# ## Punto B
#
# $$ H_{1} = 1-Z^{-1} $$
# $$ H_{2} = 1-Z^{-2} $$
#
# $H_{1}$: cero en 1
# $H_{2}$: cero doble en 1
#
# $$ H_{1}(e^{-jΩ})= 1 - e^{-jΩ}$$
#
# $$ H_{2}(e^{-jΩ})= 1 - e^{-2jΩ}$$
#
# $$ H_{1}(e^{-jΩ})= e^{\frac{-jΩ}{2}} (e^{\frac{jΩ}{2}}-e^{\frac{-jΩ}{2}}) $$
#
# $$ H_{1}(e^{-jΩ})= e^{\frac{-jΩ}{2}}2jsen(\frac{Ω}{2}) $$
#
# $$ |H_{1}(e^{-jΩ})| = 2sen(\frac{Ω}{2}) $$
#
# Para el $H_{2}$ es el mismo procedimiento y nos queda:
#
# $$ |H_{2}(e^{-jΩ})| = 2sen(Ω) $$
#
# Respuestas de fase:
#
# $$ ϕ_{1} = \Omega/2 $$
#
# $$ ϕ_{2} = \Omega $$
#
# a) El sistema $H_{1}$ introduce una demora de una muestra y el sistema $H_{2}$ introduce una demora de dos muestras.

# %%
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.freqz.html 
# Punto B - H1 
import numpy as np
import scipy.signal as signal
import matplotlib as mpl
import matplotlib.pyplot as plt
import math as m
import splane as sp

np.seterr(divide = 'ignore') 


num = [1, -1]
den = [1]
 


w,h = signal.freqz(num,den)


fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample]')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid(True)
ax2.axis('tight')
plt.show()

# %%
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.freqz.html 
# Punto B - H2 
import numpy as np
import scipy.signal as signal
import matplotlib as mpl
import matplotlib.pyplot as plt
import math as m
import splane as sp

np.seterr(divide = 'ignore') 


num = [1, 0,-1]
den = [1]
 


w,h = signal.freqz(num,den)


fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample]')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid(True)
ax2.axis('tight')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# A) $$ M(Z) = X'(Z)+a0M(Z)a1Z^{-1}+a0M(Z)a2Z^{-2} $$
#
# $$ Y(Z) = M(Z)b0 + M(Z)b1Z^{-1} + M(Z)b2Z{-2} $$
#
# $$ X'(Z) = X(Z) - c1X(Z)Z^{-N} $$
#
# $$ \frac{X'(Z)}{\frac{1}{a0}-a1Z^{-1}-a2Z^{-2}} = M(Z)  $$
#
# $$ Y(Z) = \frac{X'(Z)}{\frac{1}{a0}-a1Z^{-1}-a2Z^{-2}} ({b0+b1Z^{-1}+b2Z^{-2}}) $$
#
# $$ H(Z) = \frac{({b0+b1Z^{-1}+b2Z^{-2}})}{\frac{1}{a0}-a1Z^{-1}-a2Z^{-2}} (1 - c1Z^{-N})  $$
#
# B) $$ H_{1}(Z) = \frac{1}{3}\frac{1-Z^{-3}}{1-Z^{-1}} = \frac{1}{3} \frac{Z^{3}-1}{Z^{3}-Z^{2}} $$
#
# $$ H_{1}(e^j\Omega) = 1/3 \frac{e^{j3\Omega}-1}{e^{j3\Omega}-e^{j2\Omega}} $$
#
# $$ |H_{1}(e^j\Omega)| = \frac{1}{3}\frac{sen(\frac{3\Omega}{2})}{sen(\frac{1\Omega}{2})} $$
#
# $$ \Phi_{1} = -\Omega $$
#
# Cero triple en 1, polo doble en cero y polo simple en 1.
#
# 1. Es un filtro IIR porque tiene coeficientes de retroalimentacion de salida(a) distintos de cero
# 2.

# %%
import numpy as np
import scipy.signal as signal
import matplotlib as mpl
import matplotlib.pyplot as plt
import math as m

np.seterr(divide = 'ignore') 


num = [1/3, 0, 0, -1/3]
den = [1, -1, 0, 0]

w,h = signal.freqz(num,den)
MyFilter = signal.TransferFunction(num,den)

sp.pzmap(MyFilter)

fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample]')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid(True)
ax2.axis('tight')
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\scipy\signal\filter_design.py:475: RuntimeWarning: invalid value encountered in true_divide
#   h = (npp_polyval(zm1, b, tensor=False) /
# D:\Anaconda\lib\site-packages\numpy\lib\function_base.py:1585: RuntimeWarning: invalid value encountered in remainder
#   ddmod = mod(dd - interval_low, period) + interval_low

# %% [markdown]
#   $$ H_{2}(Z) = \frac{1}{4}\frac{1-Z^{-4}}{1-Z^{-1}} $$

# %%
import numpy as np
import scipy.signal as signal
import matplotlib as mpl
import matplotlib.pyplot as plt
import math as m
import splane as sp
num = [1/4,0,0, 0, -1/4]
den = [1,-1,0, 0, 0]

w,h = signal.freqz(num,den)
MyFilter = signal.TransferFunction(num,den)

sp.pzmap(MyFilter)


fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample]')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid(True)
ax2.axis('tight')
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\scipy\signal\filter_design.py:475: RuntimeWarning: invalid value encountered in true_divide
#   h = (npp_polyval(zm1, b, tensor=False) /
# D:\Anaconda\lib\site-packages\numpy\lib\function_base.py:1585: RuntimeWarning: invalid value encountered in remainder
#   ddmod = mod(dd - interval_low, period) + interval_low

# %% [markdown]
# $$ H_{3}(Z) = \frac{1}{5}\frac{1-Z^{-5}}{1-Z^{-1}} $$

# %%
import numpy as np
import scipy.signal as signal
import matplotlib as mpl
import matplotlib.pyplot as plt
import math as m


np.seterr(divide = 'ignore') 

num = [1/5,0,0,0,0,-1/5]
den = [1,-1,0,0,0,0]

w,h = signal.freqz(num,den)
MyFilter = signal.TransferFunction(num,den)

sp.pzmap(MyFilter)

fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample]')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid(True)
ax2.axis('tight')
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\scipy\signal\filter_design.py:475: RuntimeWarning: invalid value encountered in true_divide
#   h = (npp_polyval(zm1, b, tensor=False) /
# D:\Anaconda\lib\site-packages\numpy\lib\function_base.py:1585: RuntimeWarning: invalid value encountered in remainder
#   ddmod = mod(dd - interval_low, period) + interval_low

# %% [markdown]
# C) Para primer orden:
#
# - c1 = 0
# - a0 = 1
# - a1 = 0
# - a2 = 0
# - b0 = 1
# - b1 = 1
# - b2 = 0
#
# Para segundo orden:
#
# - c1 = 0
# - a0 = 1
# - a1 = 0
# - a2 = 0
# - b0 = 1
# - b1 = 0
# - b2 = 1

# %%
# Primer orden 
import numpy as np
import scipy.signal as signal
import matplotlib as mpl
import matplotlib.pyplot as plt
import math as m


np.seterr(divide = 'ignore') 

num = [1, -1]
den = [1]

w,h = signal.freqz(num,den)
MyFilter = signal.TransferFunction(num,den)

sp.pzmap(MyFilter)

fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample]')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid(True)
ax2.axis('tight')
plt.show()

# %%
# Segundo orden 
import numpy as np
import scipy.signal as signal
import matplotlib as mpl
import matplotlib.pyplot as plt
import math as m

np.seterr(divide = 'ignore') 


num = [1,0, -1]
den = [1]

w,h = signal.freqz(num,den)
MyFilter = signal.TransferFunction(num,den)

sp.pzmap(MyFilter)

fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample]')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid(True)
ax2.axis('tight')
plt.show()

# %% [markdown]
# D) $$ H(Z) = \frac{0.9Z}{Z-0.1} $$
#
# $$ H(e^{j\Omega}) = \frac{0.9e^{j\Omega}}{e^{j\Omega}-0.1}$$
#
# $$ e^{j\Omega} = cos(\Omega)+jsen(\Omega) $$
#
# $$ H(\Omega) = \frac{0.9}{\sqrt{(cos(\Omega)-0.1)^2+jsen(\Omega)^2}} $$
#
# Cero en cero, y polo en 0.1.
# Tipo de filtro: pasabajos con baja atenuacion en la banda de rechazo.

# %%
import numpy as np
import scipy.signal as signal
import matplotlib as mpl
import matplotlib.pyplot as plt
import math as m
import splane as sp

np.seterr(divide = 'ignore') 

num = [0.9,0]
den = [1,-0.1]

w,h = signal.freqz(num,den)
MyFilter = signal.TransferFunction(num,den)

sp.pzmap(MyFilter)

fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample]')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid(True)
ax2.axis('tight')
plt.show()

# %% [markdown]
# E) $$ H(Z) = \frac{Z-1}{Z-0.9} $$
#
# $$ H(e^{j\Omega}) = \frac{e^{j\frac{\Omega}{2}}jsen(\frac{\Omega}{2})}{e^{j\Omega}-0.9}$$
#
# Hacemos el mismo trabajo de antes:
#
# $$ |H(\Omega)| = \frac{sen(\frac{\Omega}{2})}{\sqrt{(cos(\Omega)-0.9)^2+(jsen(\Omega))^2}}$$
#
# Cero en 1 y polo en 0.9, comportamiento pasa altos y transicion abrupta hacia banda de eliminacion como se ve graficamente.
#
# Para condicion requerida:
#
# $$ \frac{1}{\sqrt{1+2x+x^2}} - 3dB = \frac{sen(0.1\pi*0.5}{\sqrt{(cos(0.1\pi-x)^2-sen(0.1\pi)^2}} $$
#
# Resuelto por calculadora:
#
# $$ x = \alpha = -0.677 $$

# %%
import numpy as np
import scipy.signal as signal
import matplotlib as mpl
import matplotlib.pyplot as plt
import math as m
import splane as sp
np.seterr(divide = 'ignore') 


num = [1,-1]
den = [1,-0.9]

w,h = signal.freqz(num,den)
MyFilter = signal.TransferFunction(num,den)

sp.pzmap(MyFilter)

fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample]')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid(True)
ax2.axis('tight')
plt.show()

# %% [markdown]
# F)
#
#
# *   a0 = 1
# *   a1 = -R
# *   b0 = R
# *   b1 = 1
# *   $R = \frac{-D}{(D+2)} $
#
# Nos queda la transferencia: $$ H(Z) = \frac{R+Z^{-1}}{1+RZ^{-1}} $$
#
# Esta transferencia hace referencia a los que vimos anteriormente como un filtro pasa todo.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $H(Z) = \frac{Z}{Z - 0.8}$
# <br><br>
# $H(e^{j\Omega}) = \frac{e^{j\Omega}}{e^{j\Omega} - 0.8}$
# <br><br>
# Evaluamos en $\Omega = \frac{\pi}{2}$ ya que conocemos la frecuencia de nuestra señal de entrada:
# <br>
# $H({e^\frac{\pi}{2}}) = \frac{e^\frac{j\pi}{2}}{e^\frac{j\pi}{2} - 0.8}$
# <br><br>
# $H({e^\frac{\pi}{2}}) = \frac{1}{1 - 0.8e^\frac{j\pi}{2}}$
# <br><br>
# Por Euler, sabiendo que $e^\frac{\pi}{2} = j1$
# <br>
# $H({e^\frac{\pi}{2}}) = \frac{1}{1 + j0.8} . \frac{1 - j0.8}{1 - j0.8}$
# <br><br>
# $H({e^\frac{\pi}{2}}) = \frac{1 - j0.8}{1 + 0.8^2}$
# <br><br>
# $H({e^\frac{\pi}{2}}) = \frac{1}{1.64}+j\frac{0.8}{1.64}$
# <br>
# ###### Modulo
# $|H({e^\frac{\pi}{2}})| = \sqrt{(\frac{1}{1.64})^2 + (\frac{0.8}{1.64})^2}$
# <br><br>
# $|H({e^\frac{\pi}{2}})| = 0.781$
# <br>
# ###### Fase
# $\phi_{H({e^\frac{\pi}{2}})} = arctg(\frac{\frac{0.8}{1.64}}{\frac{1}{1.64}}) = arctg(\frac{0.8}{1.64})$
# <br><br>
# $\phi_{H({e^\frac{\pi}{2}})} = -38.66º$
# <br><br>
# Finalmente podemos multiplicar el módulo y sumar la fase de nuestra funcion transferencia a nuestra entrada obteniendo:
# <br><br>
# $Y[n] = 20 x 0.781 cos(\frac{n\pi}{2}+30º+38.66º)$
# <br><br>
# $Y[n] = 15.62 cos(\frac{n\pi}{2}+68.66º)$

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Todos los sistemas son filtros IIR, ya que poseen retroalimentacion de la salida. Ademas, tienen la misma expresion de transferencia.  El sistema A esta en direct form 1 y los dos restantes en direct form 2.
#
# A) $$ X(Z) (a0 + a1Z^{-1} + a2Z^{-2}) = Y(Z) (1 + b1Z^{-1} + b2Z^{-2}) $$
# $$ H(Z) = \frac{a0Z^2+a1Z+a2}{Z^2+b1Z+b2} $$
#
#
# B) M(Z) Punto medio del diagrama
#
# $$ X(Z) - M(Z)Z^{-1}b1 - M(Z)Z^{-2}b2 = M(Z) $$
#
# $$ Y(Z) = M(Z)Z^{-2}a2 + M(Z)Z^{-1}a1 + M(Z)a0 $$
#
# $$ \frac{X(Z)}{1+Z^{-1}b1+Z^{-2}b2} = M(Z) $$
#
# $$ H(Z) = \frac{a0Z^2+a1Z+a2}{Z^2+b1Z+b2} $$
#
# C) $$ Y(Z) =  - Y(Z)Z^{-2}b2 - Y(Z)Z^{-1}b1 + X(Z)Z^{-2}a2 + X(Z)Z^{-1}a1 + X(Z)a0  $$
#
# $$ H(Z) = \frac{a0Z^2+a1Z+a2}{Z^2+b1Z+b2} $$
