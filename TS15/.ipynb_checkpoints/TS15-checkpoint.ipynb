# %% [markdown]
# ## Tarea semanal 15
# ### Teoria de los circuitos 2
# #### Destefano Martin
# Fecha de entrega: 3/11

# %% [markdown]
# Diseñe el cuadripolo A para que se comporte como:
#
# - Filtro pasa bajos Chebyshev de 4to. orden, 1dB de ripple
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from sympy import * 
import numpy as np 

init_printing(use_unicode = True)
s = symbols('s', relational= True)

H = 0.24565334/(s**4 + 0.095281138*s**3+1.45392476*s**2+0.74261937*s+0.27562758)
H
# Out:
#                            0.24565334
# ───────────────────────────────────────────────────────────────
#  4                3               2
# s  + 0.095281138⋅s  + 1.45392476⋅s  + 0.74261937⋅s + 0.27562758

# %%
H_negative = H.subs(s,-s)
H_negative
# Out:
#                            0.24565334
# ───────────────────────────────────────────────────────────────
#  4                3               2
# s  - 0.095281138⋅s  + 1.45392476⋅s  - 0.74261937⋅s + 0.27562758

# %%
ee = 0.2589
S21_square_module = (1)/(ee*64*s**8+128*ee*s**6+80*ee*s**4+16*ee*s**2+ee+1)
simplify(S21_square_module)
# Out:
#                            1
# ────────────────────────────────────────────────────────
#          8            6           4           2
# 16.5696⋅s  + 33.1392⋅s  + 20.712⋅s  + 4.1424⋅s  + 1.2589

# %%
S11_square_module = 1 - S21_square_module 
S11_square_module
# Out:
#                                1
# 1 - ────────────────────────────────────────────────────────
#              8            6           4           2
#     16.5696⋅s  + 33.1392⋅s  + 20.712⋅s  + 4.1424⋅s  + 1.2589

# %% [markdown]
# Para llevar esta expresion a la S11, hay que buscar las raices de denominador y numerador, luego, elegir las que se encuentren en el semiplano izquierdo.

# %%
ee = 0.2589

roots_den = np.roots([ee*64,0,128*ee,0,80*ee,0,16*ee,0,ee+1])
roots_num = np.roots([ee*64,0,128*ee,0,80*ee,0,16*ee,0,ee])

print(roots_num)
print(roots_den)
# Out:
# [-1.94270044e-08+0.92387953j -1.94270044e-08-0.92387953j
#   1.94270040e-08+0.92387953j  1.94270040e-08-0.92387953j
#   6.54448737e-09+0.38268343j  6.54448737e-09-0.38268343j
#  -6.54448762e-09+0.38268343j -6.54448762e-09-0.38268343j]
# [-0.13954045+0.98338285j -0.13954045-0.98338285j  0.13954045+0.98338285j
#   0.13954045-0.98338285j -0.33688045+0.40733051j -0.33688045-0.40733051j
#   0.33688045+0.40733051j  0.33688045-0.40733051j]

# %%
import scipy.signal as sig

num, den = sig.zpk2tf([-1.94270044e-08+0.92387953j,-1.94270044e-08-0.92387953j,-6.54448762e-09+0.38268343j,-6.54448762e-09-0.38268343j],[-0.13954045+0.98338285j,-0.13954045-0.98338285j,-0.33688045+0.40733051j,-0.33688045-0.40733051j],1/(ee*64))

print(num)
print(den)
# Out:
# [6.03514871e-02 3.13483633e-09 6.03514867e-02 1.01765745e-09
#  7.54393575e-03]
# [1.         0.9528418  1.45395375 0.74265117 0.27563833]

# %%
S11 = (6.03514871e-02*s**4+3.13483633e-09*s**3+6.03514867e-02*s**2+1.01765745e-09*s+7.54393575e-03)/(s**4+0.9528418*s**3+1.45395375*s**2+0.74265117*s+0.27563833)

print("S11: ")
S11
# Out:
# S11:
#                           0.06035149
# ─────────────────────────────────────────────────────────────
#  4              3               2
# s  + 0.9528418⋅s  + 1.45395375⋅s  + 0.74265117⋅s + 0.27563833

# %%
Z1 = (1+S11)/(1-S11)

simplify(Z1)
# Out:
#      3               2
# 2.0⋅s  + 6.19274759⋅s  + 6.07854659⋅s + 0.59505963
# ──────────────────────────────────────────────────
#                 2
#     0.20327999⋅s  + 0.62735501⋅s + 0.59505963

# %%
a1, b1 = np.polydiv([2,6.25317192,6.25950138,0.75975193], [0.14285566, 0.44640022,0.43036733])
print(a1) 
print(b1)
# Out:
# [14.00014532  0.02452803]
# [0.2233469  0.74919587]
