# %% [markdown]
# ### Ejercicio 3
#
# Dados los siguientes dipolos obtener la imepdacia de excitacion. Discutir los siguientes aspectos para cada circuito:
#
# A. Discutir la naturaleza de la Zin (capacitiva, inductiva o resistiva)
# B. Como se ve afectadada la Zin por los elementos circuitales
# C. Posibles utilidades del circuito
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Circuito 1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# $$\frac{V_{o}-V_{i}}{R_{2}}+V_{i}sC_{1}=I_{1}(1) \\
# V_{i}sC_{1}=-\frac{V_{o}}{R_{1}}(2) $$
#
# De (2)
#
# $$V_{o} = -V_{i}sC_{1}R_{1}$$
#
# En (1)
#
# $$\frac{-V_{i}sC_{1}R_{1}-V_{i}}{R_{2}}+V_{i}sC_{1}=I_{1} \\
# \frac{V_{i}}{I_{1}} = -\frac{R_{2}}{SC_{1}(R1-R2)-1}$$

# %% [markdown]
# Circuito 2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Circuito 3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ (V_{o}-V_{i})sC_{1} = I_{1}' \\
# \frac{V_{o}}{R_{2}} = -\frac{V_{i}}{R_{1}} \\
# V_{o} = \frac{-V_{i}}{R_{1}}R_{2} \\
# (-\frac{V_{i}}{R_{1}}R_{2}-V_{i})sC_{1} = I_{1} \\
# \frac{V_{i}}{I_{1}} = -\frac{R_{1}}{R_{2}sC_{1}+sC_{1}R_{1}} = -\frac{R1}{s(C_{1}R_{1}+C_{1}R_{1})} $$

# %% [markdown]
# Circuito 4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### SIMULACION EJERCICIO 8 V1/Vin

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### SIMULACION EJERCICIO 8 V2/Vin

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### SIMULACION EJERCICIO 8 V3/Vin

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from IPython.display import IFrame
IFrame("./TP1 2021 R4052_01.pdf", width=800, height=400)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="./TP1 2021 R4052_01.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
