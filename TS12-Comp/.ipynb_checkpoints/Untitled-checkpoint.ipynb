# %% [markdown]
# ![utn.svg](logo_utn.svg)
#
# ## Tarea semanal 12 - Competitiva
#
# #### Destefano Martin
#
# #### 23/09/2022
#
# Dada la siguiente estructura activa:
#
# ![image-3.png](attachment:image-3.png)
#
# Donde el conversor de impedancia negativa corresponde a un VNIC, y las redes (a) y (b) a sendas redes pasivas de tipo RC, se pide:
#
# a) Demostrar que la transimpedancia total V2I1 del circuito en vacío es igual a:
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Desarrollo en papel:
# ![Imagen2.jpeg](2.jpg)

# %% [markdown]
# b) Separando en fracciones simples y aplicando conceptos síntesis directa, proponer dos cuadripolos RC pasivos (A) y (B) tal que la transimpedancia del sistema se corresponda a una respuesta de tipo Butterworth pasabajos normalizada de orden 3.

# %% [markdown]
# Desarrollo en papel:
# ![desarrollo2parteA](3.jpg)
# ![desarrollo2parteB](1.jpg)

# %% [markdown]
# Simulacion:
# ![image-6.png](attachment:image-6.png)
# Utilizo una fuente de corriente porque tengo un capacitor en paralelo, el usar una fuente de tension seria erroneo, ya que el capacitor no cumpliria ninguna funcion.
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# Vemos que en la banda de paso aparece una pequeña ganancia (podria mejorarse con el k que es la relacion de R2/R1), y que a la frecuencia normalizada aparecen los 3dB caracteristicos.

# %% [markdown]
# Utiles:
#
# Video VNIC y INIC:
# [Video Mariano](https://www.youtube.com/watch?v=Phr5Ycq3PlM)
#
# [Video 2 Mariano](https://www.youtube.com/watch?v=TvPhC5QaHcc&ab_channel=MarianoLlamedoSoria)
#
# Paper: https://drive.google.com/file/d/0BzkNc2SH4P7ULUpMcUtGbzRiTWM/view?resourcekey=0-X0kXG5UEoSHMH38WeRnq7Q
